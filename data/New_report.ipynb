# %%
import pandas as pd
df = pd.read_csv('exported-patient-data.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20020\3825465295.py in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv('exported-patient-data.csv')
# ----> 3 df.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df['New_target']= df['target'].map({1:'Active',0:'inactive'})

# %%
df
# Out:
#      Unnamed: 0  age  trestbps  restecg  thalach  exang  oldpeak  slope  \
# 0             0   63       145        0      150      0      2.3    NaN
# 1             1   37       130        1      187      0      3.5    NaN
# 2             2   41       130        0      172      0      1.4    NaN
# 3             3   56       120        1      178      0      0.8    NaN
# 4             4   57       120        1      163      1      0.6    NaN
# ..          ...  ...       ...      ...      ...    ...      ...    ...
# 298         298   57       140        1      123      1      0.2    NaN
# 299         299   45       110        1      132      0      1.2    NaN
# 300         300   68       144        1      141      0      3.4    NaN
# 301         301   57       130        1      115      1      1.2    NaN
# 302         302   57       130        0      174      0      0.0    NaN
#
#     New_target
# 0       Active
# 1       Active
# 2       Active
# 3       Active
# 4       Active
# ...
